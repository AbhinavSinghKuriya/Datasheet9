# %%
#imports 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.impute import KNNImputer

# %%
df=pd.read_csv("cust_segmentation_Data.csv")
print(df.index)
print("All columns are")
ai=0
for i in df:
    print(ai,i)
    ai+=1
# Out:
# RangeIndex(start=0, stop=850, step=1)
# All columns are
# 0 Customer Id
# 1 Age
# 2 Edu
# 3 Years Employed
# 4 Income
# 5 Card Debt
# 6 Other Debt
# 7 Defaulted
# 8 DebtIncomeRatio

# %%
df.sample(n=10)
# Out:
#      Customer Id  Age  Edu  Years Employed  Income  Card Debt  Other Debt  \
# 448          449   47    1              17      43      0.588       1.820
# 183          184   47    1              29     129     20.561      12.076
# 755          756   47    1               4      26      0.122       2.582
# 36            37   35    3               5      37      0.581       1.417
# 468          469   31    1              15      60      0.804       2.076
# 569          570   26    1               4      20      0.319       0.761
# 836          837   23    2               3      24      0.552       0.960
# 442          443   36    1               6      26      0.030       2.128
# 221          222   40    3              17     116      2.561       4.399
# 426          427   43    1               4      29      0.053       1.281
#
#      Defaulted  DebtIncomeRatio
# 448        0.0              5.6
# 183        1.0             25.3
# 755        0.0             10.4
# 36         1.0              5.4
# 468        0.0              4.8
# 569        0.0              5.4
# 836        0.0              6.3
# 442        0.0              8.3
# 221        0.0              6.0
# 426        0.0              4.6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer Id      850 non-null    int64
#  1   Age              850 non-null    int64
#  2   Edu              850 non-null    int64
#  3   Years Employed   850 non-null    int64
#  4   Income           850 non-null    int64
#  5   Card Debt        850 non-null    float64
#  6   Other Debt       850 non-null    float64
#  7   Defaulted        700 non-null    float64
#  8   DebtIncomeRatio  850 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 59.9 KB

# %%
print(df.isnull().sum())
print('Defaulted has 150 null values')
# Out:
# Customer Id          0
# Age                  0
# Edu                  0
# Years Employed       0
# Income               0
# Card Debt            0
# Other Debt           0
# Defaulted          150
# DebtIncomeRatio      0
# dtype: int64
# Defaulted has 150 null values

# %%
# Filling Defaulted missing values with KNN Imputer

imputer = KNNImputer(n_neighbors=5)

df["Defaulted"] = imputer.fit_transform(df[["Age", "Edu", "Years Employed", "Income", 
                                            "Card Debt", "Other Debt", "DebtIncomeRatio", "Defaulted"]])[:, -1]

df["Defaulted"] = df["Defaulted"].round().astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer Id      850 non-null    int64
#  1   Age              850 non-null    int64
#  2   Edu              850 non-null    int64
#  3   Years Employed   850 non-null    int64
#  4   Income           850 non-null    int64
#  5   Card Debt        850 non-null    float64
#  6   Other Debt       850 non-null    float64
#  7   Defaulted        850 non-null    int64
#  8   DebtIncomeRatio  850 non-null    float64
# dtypes: float64(3), int64(6)
# memory usage: 59.9 KB

# %%
print(df.isnull().sum())
print('Defaulted has now 0 null values')
# Out:
# Customer Id        0
# Age                0
# Edu                0
# Years Employed     0
# Income             0
# Card Debt          0
# Other Debt         0
# Defaulted          0
# DebtIncomeRatio    0
# dtype: int64
# Defaulted has now 0 null values
