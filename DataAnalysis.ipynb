# %%
#imports 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("cust_segmentation_Data.csv")
print(df.index)
print("All columns are")
ai=0
for i in df:
    print(ai,i)
    ai+=1
# Out:
# RangeIndex(start=0, stop=850, step=1)
# All columns are
# 0 Customer Id
# 1 Age
# 2 Edu
# 3 Years Employed
# 4 Income
# 5 Card Debt
# 6 Other Debt
# 7 Defaulted
# 8 DebtIncomeRatio

# %%
df.shape

# %%
df.head()
# Out:
#    Customer Id  Age  Edu  Years Employed  Income  Card Debt  Other Debt  \
# 0            1   41    2               6      19      0.124       1.073
# 1            2   47    1              26     100      4.582       8.218
# 2            3   33    2              10      57      6.111       5.802
# 3            4   29    2               4      19      0.681       0.516
# 4            5   47    1              31     253      9.308       8.908
#
#    Defaulted  DebtIncomeRatio
# 0        0.0              6.3
# 1        0.0             12.8
# 2        1.0             20.9
# 3        0.0              6.3
# 4        0.0              7.2

# %%
df.sample(n=10)
# Out:
#      Customer Id  Age  Edu  Years Employed  Income  Card Debt  Other Debt  \
# 92            93   31    1               1      21      0.277       0.248
# 251          252   26    3               2      37      0.205       5.049
# 605          606   39    1              16      57      1.559       9.499
# 276          277   24    2               2      28      1.787       3.057
# 473          474   41    1              19      96      2.254       5.234
# 40            41   20    1               4      14      0.201       1.157
# 788          789   33    2               8      27      1.646       1.000
# 365          366   28    1               2      16      0.871       1.561
# 782          783   35    1              10      39      0.218       2.005
# 684          685   21    3               0      24      0.833       1.015
#
#      Defaulted  DebtIncomeRatio
# 92         1.0              2.5
# 251        0.0             14.2
# 605        0.0             19.4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer Id      850 non-null    int64
#  1   Age              850 non-null    int64
#  2   Edu              850 non-null    int64
#  3   Years Employed   850 non-null    int64
#  4   Income           850 non-null    int64
#  5   Card Debt        850 non-null    float64
#  6   Other Debt       850 non-null    float64
#  7   Defaulted        700 non-null    float64
#  8   DebtIncomeRatio  850 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 59.9 KB

# %%
df.isnull()
# Out:
#      Customer Id    Age    Edu  Years Employed  Income  Card Debt  Other Debt  \
# 0          False  False  False           False   False      False       False
# 1          False  False  False           False   False      False       False
# 2          False  False  False           False   False      False       False
# 3          False  False  False           False   False      False       False
# 4          False  False  False           False   False      False       False
# ..           ...    ...    ...             ...     ...        ...         ...
# 845        False  False  False           False   False      False       False
# 846        False  False  False           False   False      False       False
# 847        False  False  False           False   False      False       False
# 848        False  False  False           False   False      False       False
# 849        False  False  False           False   False      False       False
#
#      Defaulted  DebtIncomeRatio
# ...

# %%
print(df.isnull().sum())
print('Defaulted has 150 null values')
# Out:
# Customer Id          0
# Age                  0
# Edu                  0
# Years Employed       0
# Income               0
# Card Debt            0
# Other Debt           0
# Defaulted          150
# DebtIncomeRatio      0
# dtype: int64
# Defaulted has 150 null values

# %%
df.describe()
# Out:
#        Customer Id         Age         Edu  Years Employed      Income  \
# count    850.00000  850.000000  850.000000      850.000000  850.000000
# mean     425.50000   35.029412    1.710588        8.565882   46.675294
# std      245.51816    8.041432    0.927784        6.777884   38.543054
# min        1.00000   20.000000    1.000000        0.000000   13.000000
# 25%      213.25000   29.000000    1.000000        3.000000   24.000000
# 50%      425.50000   34.000000    1.000000        7.000000   35.000000
# 75%      637.75000   41.000000    2.000000       13.000000   55.750000
# max      850.00000   56.000000    5.000000       33.000000  446.000000
#
#         Card Debt  Other Debt   Defaulted  DebtIncomeRatio
# count  850.000000  850.000000  700.000000       850.000000
# mean     1.576820    3.078773    0.261429        10.171647
# std      2.125843    3.398799    0.439727         6.719441
# min      0.012000    0.046000    0.000000         0.100000
# ...

# %%
# Plotting only useful columns
grid = sns.pairplot(df,corner=True)

# %%
# For saving the plot
'''

grid.savefig('segmentationpairplot.png', dpi=300, bbox_inches='tight')


'''
print('This plot gives us a rough idea of the data')
# Out:
# This plot gives us a rough idea of the data

# %%
plt.figure(figsize=(11,10))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Customer Id', 'Age', 'Edu', 'Years Employed', 'Income', 'Card Debt',
#        'Other Debt', 'Defaulted', 'DebtIncomeRatio'],
#       dtype='object')

# %%
churnplot = sns.pairplot(
            df,
            vars=['Customer Id', 'Age', 'Edu', 'Years Employed', 'Income', 'Card Debt',
                  'Other Debt', 'DebtIncomeRatio'],
            hue='Defaulted',
            plot_kws={'alpha':0.5},
            corner = True
            )

# %%
'''

churnplot.savefig('segmentationchurn.png', dpi=300, bbox_inches='tight')

'''
